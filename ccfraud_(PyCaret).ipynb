# %% [markdown]
# ##Loading libraries and file

# %%
# !pip install pycaret

# %%
from google.colab import files

files.upload()
#for fn in uploaded.keys():
#  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-14b5a059-5a7f-4b5c-af15-77f0ba8e1813" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14b5a059-5a7f-4b5c-af15-77f0ba8e1813">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving creditcard.csv to creditcard.csv

# %%
from pycaret import *
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# ##Data loaded, now explore

# %%
# occurances of no fraud
len(df[df['Class']==0])
# Out:
# 284315

# %%
# occurances of fraud
len(df[df['Class']==1])
# Out:
# 492

# %% [markdown]
# 'Class' is the target variable.
#
# Amount of fraud compared to no fraud is very lopsided.

# %% [markdown]
# ### Let's keep cleaning and anlayzing

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ##Initializing model setup

# %%
from pycaret.classification import *
clf1 = setup(data = df, target = 'Class')
# Out:
#                                Description             Value
# 0                               session_id              4845
# 1                                   Target             Class
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data      (284807, 31)
# 5                           Missing Values             False
# 6                         Numeric Features                30
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set      (199364, 30)
# 12                    Transformed Test Set       (85443, 30)
# 13                      Shuffle Train-Test              True
# ...

# %% [markdown]
# ##Model comparison

# %%
accurate = compare_models(n_select=3) #default is accuracy
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.9995  0.9446  0.7819  0.9252
# et                 Extra Trees Classifier    0.9995  0.9505  0.7791  0.9330
# dt               Decision Tree Classifier    0.9992  0.8832  0.7668  0.7524
# ada                  Ada Boost Classifier    0.9992  0.9686  0.7074  0.8030
# lr                    Logistic Regression    0.9991  0.9493  0.5734  0.8201
# ridge                    Ridge Classifier    0.9988  0.0000  0.3911  0.7901
# knn                K Neighbors Classifier    0.9983  0.6000  0.0209  0.5500
# svm                   SVM - Linear Kernel    0.9983  0.0000  0.0000  0.0000
# dummy                    Dummy Classifier    0.9983  0.5000  0.0000  0.0000
# lightgbm  Light Gradient Boosting Machine    0.9959  0.5892  0.3669  0.1798
# nb                            Naive Bayes    0.9924  0.9707  0.6503  0.1340
# ...

# %%
comp_auc = compare_models(n_select= 3,sort = 'AUC')
# Out:
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# qda    Quadratic Discriminant Analysis    0.9760  0.9721  0.8742  0.0581
# nb                         Naive Bayes    0.9924  0.9707  0.6503  0.1340
# lr                 Logistic Regression    0.9991  0.9493  0.5734  0.8201
# lda       Linear Discriminant Analysis    0.9994  0.9028  0.7730  0.8440
# dt            Decision Tree Classifier    0.9992  0.8832  0.7668  0.7524
# knn             K Neighbors Classifier    0.9983  0.6000  0.0209  0.5500
# dummy                 Dummy Classifier    0.9983  0.5000  0.0000  0.0000
# svm                SVM - Linear Kernel    0.9983  0.0000  0.0000  0.0000
# ridge                 Ridge Classifier    0.9988  0.0000  0.3911  0.7901
#
#            F1   Kappa     MCC  TT (Sec)
# qda    0.1090  0.1062  0.2219     0.867
# nb     0.2221  0.2199  0.2928     0.173
# lr     0.6716  0.6712  0.6836     8.815
# lda    0.8062  0.8059  0.8071     1.358
# ...

# %%
accurate
# Out:
# [RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=None, max_features='auto',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=-1, oob_score=False, random_state=4378, verbose=0,
#                         warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                       criterion='gini', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, max_samples=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
# ...

# %%
print(comp_auc)
# Out:
# [QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001), GaussianNB(priors=None, var_smoothing=1e-09), LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=4378, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)]

# %% [markdown]
# ##I will pick ada (AdaBoostClassifier) for my model
# ###It's balanced in both accuracy and auc

# %%
ada = create_model('ada')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9992  0.9774  0.7143  0.8065  0.7576  0.7572  0.7586
# 1       0.9992  0.9907  0.8286  0.7436  0.7838  0.7834  0.7845
# 2       0.9991  0.9881  0.6857  0.7742  0.7273  0.7268  0.7282
# 3       0.9994  0.9892  0.7429  0.8966  0.8125  0.8122  0.8158
# 4       0.9994  0.9729  0.7941  0.8710  0.8308  0.8305  0.8314
# 5       0.9990  0.9710  0.7059  0.7273  0.7164  0.7159  0.7160
# 6       0.9991  0.9325  0.6286  0.8462  0.7213  0.7209  0.7289
# 7       0.9993  0.9973  0.6857  0.9231  0.7869  0.7866  0.7953
# 8       0.9992  0.9619  0.7143  0.8065  0.7576  0.7572  0.7586
# 9       0.9993  0.9373  0.6286  0.9565  0.7586  0.7583  0.7751
# Mean    0.9992  0.9718  0.7129  0.8351  0.7653  0.7649  0.7692
# SD      0.0001  0.0211  0.0605  0.0728  0.0364  0.0365  0.0365

# %%
ada
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=4845)

# %%
plot_auc = plot_model(ada,plot='auc')

# %%
plot_cnmx = plot_model(ada, plot='confusion_matrix')

# %%
plot_ft = plot_model(ada, plot='feature')

# %%
evaluate_model(ada)

# %%
final = finalize_model(ada)
final
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-79d4fc76c6df> in <module>()
# ----> 1 final = finalize_model(ada)
#       2 final
#
# /usr/local/lib/python3.7/dist-packages/pycaret/classification.py in finalize_model(estimator, fit_kwargs, groups, model_only)
#    2066         fit_kwargs=fit_kwargs,
#    2067         groups=groups,
# -> 2068         model_only=model_only,
#    2069     )
#    2070
#
# /usr/local/lib/python3.7/dist-packages/pycaret/internal/tabular.py in finalize_model(estimator, fit_kwargs, groups, model_only, display)
#    8916         fit_kwargs=fit_kwargs,
#    8917         groups=groups,
# -> 8918         add_to_model_list=False,
#    8919     )
#    8920     model_results = pull(pop=True)
#
# ...

# %% [markdown]
# ## HyperParameter Tuning

# %%
tuned = tune_model(ada)
# Out:
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   20:04:36
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .       Ada Boost Classifier
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-0a40145f6e32> in <module>()
# ----> 1 tuned = tune_model(ada)
#
# ...
