# %%
import random
while True:
    player = input("CHOOSE rock, paper or scissors.")
    choices = ["rock", "paper", "scissors"]
    computer = random.choice(choices)
    print(f"\nYou chose {player}, computer chose {computer}.\n")

    if player == computer :
        print("UH-OH BOTH PLAYERS SELECTED {player}. IT'S A TIE!"
    elif player == "rock" :
        if computer == "paper":
            print("LOSER! PAPER COVERS ROCK"
        else:
            print("WINNER! ROCK SMASHES SCISSORS")
    elif player == "paper" :
        if computer == "rock":
            print("WINNER! PAPER COVERS ROCK"
        else:
            print("LOSER! SCISSORS CUTS PAPER")
    elif player == "scissors" :
            if computer == "rock":
                print(LOSER! ROCK SMASHES SCISSORS")
            else:
                print("WINNER! SCISSORS CUTS PAPER"

    again = input("PLAY AGAIN? (y/n):"
    if again.lower() != "y":
        break
# Out:
#   File "<ipython-input-3-d9b7930f356a>", line 10
#     elif player == "rock" :
#        ^
# SyntaxError: invalid syntax

# %%
import random
while True:
    player = input("CHOOSE rock, paper or scissors.")
    choices = ["rock", "paper", "scissors"]
    computer = random.choice(choices)
    print(f"\nYou chose {player}, computer chose {computer}.\n")

    if player == computer :
        print(f"UH-OH BOTH PLAYERS SELECTED {player}. IT'S A TIE!")
    elif player == "rock" :
        if computer == "paper":
            print("LOSER! PAPER COVERS ROCK")
        else:
            print("WINNER! ROCK SMASHES SCISSORS")
    elif player == "paper" :
        if computer == "rock":
            print("WINNER! PAPER COVERS ROCK")
        else:
            print("LOSER! SCISSORS CUTS PAPER")
    elif player == "scissors" :
        if computer == "rock":
            print("LOSER! ROCK SMASHES SCISSORS")
        else:
            print("WINNER! SCISSORS CUTS PAPER")

    again = input("PLAY AGAIN? (y/n):")
    if again.lower() != "y":
        break
# Out:
# You chose asda, computer chose rock.
#
#
# You chose paper, computer chose scissors.
#
# LOSER! SCISSORS CUTS PAPER
